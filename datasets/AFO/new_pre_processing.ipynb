# %%
import os
import shutil
from PIL import Image # Para verificar dimensões da imagem para os bboxes
import matplotlib.pyplot as plt # Para visualização de bboxes
import matplotlib.patches as patches # Para desenhar retângulos
import cv2 # Usado na seção de verificação opcional, pode ser necessário para ler imagens

# %%
import os
import shutil

# --- Configurações de Caminho ---

# Define o caminho base onde todas as imagens serão CENTRALIZADAS.
# Crie este diretório se ele não existir.
# Exemplo: Se você quer que todas as imagens fiquem em 'AFO/all_images_here',
# defina ORIGINAL_DATA_BASE_PATH = 'AFO/all_images_here'
# VOU ASSUMIR QUE VOCÊ QUER JUNTAR TUDO NA RAIZ DO PROJETO OU EM UMA NOVA PASTA DEDICADA
# Ajuste conforme sua preferência, por exemplo, 'merged_images' ou 'all_dataset_images'
FINAL_MERGED_IMAGE_DIR = "all_dataset_images" # Nome da pasta para juntar todas as imagens

# Certifica-se de que a pasta de destino final existe
if not os.path.exists(FINAL_MERGED_IMAGE_DIR):
    os.makedirs(FINAL_MERGED_IMAGE_DIR)
    print(f"Pasta de destino '{FINAL_MERGED_IMAGE_DIR}' criada.")

# Diretórios de onde as imagens serão COLETADAS
image_dirs = [
    'PART_1/PART_1/images',
    'PART_2/PART_2/images',
    'PART_3/PART_3/images'
]

# Extensões de arquivo de imagem que serão consideradas
IMAGE_EXTENSIONS = ('.jpg', '.jpeg', '.png', '.gif', '.bmp', '.tiff', '.webp')

# --- Processo de Junção de Imagens ---

print("\nIniciando a cópia das imagens...")
copied_image_count = 0

for source_dir in image_dirs:
    # Verifica se o diretório de origem existe antes de tentar listar
    if not os.path.exists(source_dir):
        print(f"Aviso: Diretório de origem '{source_dir}' não encontrado. Pulando...")
        continue

    print(f"Processando diretório: {source_dir}")
    for fname in os.listdir(source_dir):
        # Verifica se o arquivo é uma imagem pela extensão
        if fname.lower().endswith(IMAGE_EXTENSIONS):
            source_image_path = os.path.join(source_dir, fname)

            # Para evitar sobrescrever imagens com o mesmo nome vindo de pastas diferentes,
            # adicionamos um sufixo único ao nome do arquivo.
            # Uma forma simples é usar um contador ou adicionar o nome da pasta de origem.
            # Aqui, vou usar um contador global para manter os nomes curtos.
            
            base_name, extension = os.path.splitext(fname)
            destination_image_name = f"{base_name}{extension}"
            destination_image_path = os.path.join(FINAL_MERGED_IMAGE_DIR, destination_image_name)

            try:
                shutil.copy2(source_image_path, destination_image_path)
                # print(f"Copiado: {source_image_path} -> {destination_image_path}")
                copied_image_count += 1
            except Exception as e:
                print(f"ERRO ao copiar '{source_image_path}': {e}")

print(f"\nProcesso concluído. Total de {copied_image_count} imagens copiadas para '{FINAL_MERGED_IMAGE_DIR}'.")
# Out:
# Pasta de destino 'all_dataset_images' criada.
#
# Iniciando a cópia das imagens...
# Processando diretório: PART_1/PART_1/images
# Processando diretório: PART_2/PART_2/images
# Processando diretório: PART_3/PART_3/images
#
# Processo concluído. Total de 3641 imagens copiadas para 'all_dataset_images'.

# %% [markdown]
# ## 2. Funções Auxiliares

# %%
def load_class_names(filepath):
    """Carrega os nomes das classes do arquivo .names"""
    try:
        with open(filepath, 'r') as f:
            return [line.strip() for line in f.readlines()]
    except FileNotFoundError:
        print(f"Erro: Arquivo de nomes de classes não encontrado em {filepath}")
        return None

def get_target_indices(all_class_names, target_names):
    """Obtém os índices das classes de interesse"""
    if not all_class_names:
        return []
    target_indices = []
    for name in target_names:
        try:
            target_indices.append(all_class_names.index(name))
        except ValueError:
            print(f"Aviso: Classe de interesse '{name}' não encontrada na lista de classes do dataset.")
    return target_indices

def convert_yolo_to_absolute(x_center_norm, y_center_norm, width_norm, height_norm, img_width, img_height):
    """Converte coordenadas YOLO normalizadas para absolutas [xmin, ymin, xmax, ymax]."""
    w_abs = width_norm * img_width
    h_abs = height_norm * img_height
    x_min_abs = (x_center_norm * img_width) - (w_abs / 2)
    y_min_abs = (y_center_norm * img_height) - (h_abs / 2)
    x_max_abs = x_min_abs + w_abs
    y_max_abs = y_min_abs + h_abs
    return int(x_min_abs), int(y_min_abs), int(x_max_abs), int(y_max_abs)

# %% [markdown]
# ## 3. Script Principal de Limpeza e Cópia

# %%
def process_dataset():
    # Usar as variáveis globais definidas na Célula 4
    image_path_original = 'all_dataset_images'
    annotation_path_original = ANNOTATION_DIR_ORIGINAL
    class_names_filepath = CLASS_NAMES_FILE_ORIGINAL

    # O restante das definições de output_..._path já usa OUTPUT_ROOT_DIR, o que está correto
    output_image_path = os.path.join(OUTPUT_ROOT_DIR, OUTPUT_IMAGE_DIR_NAME)
    output_annotation_path = os.path.join(OUTPUT_ROOT_DIR, OUTPUT_ANNOTATION_DIR_NAME)

    # Verifica novamente se os caminhos de entrada são válidos
    if not os.path.isdir(image_path_original):
        print(f"ERRO: Diretório de imagens original '{image_path_original}' não encontrado. Verifique as configurações.")
        return
    if not os.path.isdir(annotation_path_original):
        print(f"ERRO: Diretório de anotações original '{annotation_path_original}' não encontrado. Verifique as configurações.")
        return
    if not os.path.isfile(class_names_filepath):
        print(f"ERRO: Arquivo de nomes de classes '{class_names_filepath}' não encontrado. Verifique as configurações.")
        return


    output_image_path = os.path.join(OUTPUT_ROOT, OUTPUT_IMAGE_DIR_NAME)
    output_annotation_path = os.path.join(OUTPUT_ROOT, OUTPUT_ANNOTATION_DIR_NAME)

    # Cria diretórios de saída se não existirem
    os.makedirs(output_image_path, exist_ok=True)
    os.makedirs(output_annotation_path, exist_ok=True)
    print(f"Diretório de saída para imagens limpas: {output_image_path}")
    print(f"Diretório de saída para anotações limpas: {output_annotation_path}")

    all_classes = load_class_names(class_names_filepath)
    if not all_classes:
        return

    target_indices = get_target_indices(all_classes, TARGET_CLASS_NAMES)
    if not target_indices:
        print("Nenhuma classe de interesse válida foi identificada. Saindo.")
        return

    print(f"\nClasses carregadas: {all_classes}")
    print(f"Índices das classes de interesse: {target_indices} ({[all_classes[i] for i in target_indices if i < len(all_classes)]})")

    processed_images_count = 0
    skipped_images_count = 0
    
    try:
        original_annotation_files = [f for f in os.listdir(annotation_path_original) if f.endswith('.txt')]
    except FileNotFoundError:
        print(f"ERRO: Não foi possível listar arquivos em '{annotation_path_original}'. O caminho está correto?")
        return
        
    print(f"Encontrados {len(original_annotation_files)} arquivos de anotação em '{annotation_path_original}'.")


    for ann_filename in original_annotation_files:
        base_filename = os.path.splitext(ann_filename)[0]
        
        # Tenta encontrar a imagem correspondente (comum ser .jpg, .png)
        # Adicione outras extensões se necessário (ex: .jpeg)
        possible_img_extensions = [".jpg", ".png", ".jpeg"]
        original_img_filepath = None
        img_extension = None

        for ext in possible_img_extensions:
            temp_img_path = os.path.join(image_path_original, base_filename + ext)
            if os.path.exists(temp_img_path):
                original_img_filepath = temp_img_path
                img_extension = ext
                break
        
        if not original_img_filepath:
            print(f"Aviso: Imagem correspondente para {ann_filename} não encontrada com extensões {possible_img_extensions}. Pulando.")
            continue
        
        current_ann_filepath = os.path.join(annotation_path_original, ann_filename)
        
        filtered_annotations = []
        try:
            with open(current_ann_filepath, 'r') as f_ann:
                lines = f_ann.readlines()
                for line in lines:
                    parts = line.strip().split()
                    if not parts: # Linha vazia
                        continue
                    
                    try:
                        class_id = int(parts[0])
                        if class_id in target_indices:
                            # A linha já está no formato YOLO (classe_id x y w h)
                            # Apenas garantimos que tenha 5 partes (id + 4 coords)
                            if len(parts) == 5:
                                filtered_annotations.append(line.strip())
                            else:
                                print(f"Aviso: Linha em {ann_filename} com classe de interesse mas formato inesperado (num partes != 5): '{line.strip()}'")
                        
                    except (ValueError, IndexError):
                        print(f"Aviso: Linha mal formatada em {ann_filename}: '{line.strip()}'")
                        continue
        except Exception as e:
            print(f"Erro ao ler o arquivo de anotação {ann_filename}: {e}")
            continue

        if filtered_annotations:
            # Salva o novo arquivo de anotação
            new_ann_filepath = os.path.join(output_annotation_path, ann_filename)
            with open(new_ann_filepath, 'w') as f_new_ann:
                for ann_line in filtered_annotations:
                    f_new_ann.write(ann_line + '\n')
            
            # Copia a imagem correspondente
            new_img_filepath = os.path.join(output_image_path, base_filename + img_extension)
            try:
                shutil.copy2(original_img_filepath, new_img_filepath)
                processed_images_count += 1
            except Exception as e:
                print(f"Erro ao copiar a imagem {original_img_filepath} para {new_img_filepath}: {e}")
        else:
            skipped_images_count += 1
            # print(f"Imagem {base_filename} não continha objetos de interesse. Não será copiada.")

    print(f"\nProcessamento concluído.")
    print(f"Total de imagens processadas e salvas no novo dataset: {processed_images_count}")
    print(f"Total de imagens originais ignoradas (sem objetos de interesse ou erro na imagem): {skipped_images_count}")

# Executa a função principal de processamento
process_dataset()
# Out:
# Diretório de saída para imagens limpas: /datasets\images
# Diretório de saída para anotações limpas: /datasets\labels
#
# Classes carregadas: ['human', 'wind/sup-board', 'boat', 'bouy', 'sailboat', 'kayak']
# Índices das classes de interesse: [0, 2, 4, 5] (['human', 'boat', 'sailboat', 'kayak'])
# Encontrados 3641 arquivos de anotação em 'PART_1/PART_1\6categories'.
# Aviso: Imagem correspondente para ev_1030.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para ev_1226.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para ev_363.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para ev_463.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para ev_546.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para ev_644.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para ev_914.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_0.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_1.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_10.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_11.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_12.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_13.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_14.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_15.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_16.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_17.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_18.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_19.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_2.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_20.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_21.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_22.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_23.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_24.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_25.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_26.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_27.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_28.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_29.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_3.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_30.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_31.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_32.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_33.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_34.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_35.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_36.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_37.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_38.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_39.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_4.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_40.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_41.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_42.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_43.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_44.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_45.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_46.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_47.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_48.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_49.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_5.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_50.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_51.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_52.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_53.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_54.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_55.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_56.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_57.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_58.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_59.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_6.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_60.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_61.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_62.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_63.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_64.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_65.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_66.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_67.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_68.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_69.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_7.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_70.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_71.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_72.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_73.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_74.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_75.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_76.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_77.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_78.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_79.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_8.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_80.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_81.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_82.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_83.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_84.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_85.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_86.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_87.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_88.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_89.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_9.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_90.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_91.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_92.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_93.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_94.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_95.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_96.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_97.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_98.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para e_99.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para fv_311.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para fv_386.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para fv_474.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para fv_9.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_100.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_101.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_102.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_103.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_104.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_105.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_106.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_107.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_108.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_109.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_110.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_111.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_112.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_113.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_114.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_115.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_116.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_117.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_118.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_119.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_120.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_121.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_122.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_123.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_124.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_125.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_126.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_81.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_82.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_83.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_84.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_85.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_86.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_87.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_88.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_89.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_90.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_91.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_92.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_93.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_94.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_95.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_96.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_97.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_98.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para f_99.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_145.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_146.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_147.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_148.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_149.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_150.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_151.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_152.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_153.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_154.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_155.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_156.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_157.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_158.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_159.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_160.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_161.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_162.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_163.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_171.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_172.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_173.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_174.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_175.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_176.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_177.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_178.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_179.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_180.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_181.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_182.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_186.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_187.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_188.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_189.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_190.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_191.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_192.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_193.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_194.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_195.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_196.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_197.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_198.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_199.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_200.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_201.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_203.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_33.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_34.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_35.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_36.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_37.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_38.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_39.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_40.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_41.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_42.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_43.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_44.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_45.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_50.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_51.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_52.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_53.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_54.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_55.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_56.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_57.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_58.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_59.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_60.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_61.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_62.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_63.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_64.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_65.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_66.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_67.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_68.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_69.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_70.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_71.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_77.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_78.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_79.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_80.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_81.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_82.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_83.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_84.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_85.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para g_86.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i1_0.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i1_1.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i1_10.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i1_11.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i1_12.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i1_13.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i1_14.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i1_15.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i1_16.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i1_4.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i1_5.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i1_6.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i1_7.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i1_8.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i1_9.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i2_155.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i2_156.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i2_157.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i2_158.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i2_159.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i2_160.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i2_161.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i2_162.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i2_163.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i2_164.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_132.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_133.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_134.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_135.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_136.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_137.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_138.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_139.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_140.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_141.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_142.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_143.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_144.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_145.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_146.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_147.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_148.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_149.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_150.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_151.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_152.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_153.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_154.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_155.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_156.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_157.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_158.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_159.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_160.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_161.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_162.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_163.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_164.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_165.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_166.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_167.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_168.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_169.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_170.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_171.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_172.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_173.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_174.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_175.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_176.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_177.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_178.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_179.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_180.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_181.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_182.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_183.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_184.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_185.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_186.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_187.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_188.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_189.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_190.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_191.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_192.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_193.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_194.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_195.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_196.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_197.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_198.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_199.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para i3_200.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para iv_106.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para iv_118.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para iv_120.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para iv_265.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para iv_267.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para iv_269.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para iv_272.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para iv_277.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para iv_282.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j1_151.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j1_152.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j1_153.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j1_154.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j1_155.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j1_156.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j1_157.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j1_158.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j1_159.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j1_160.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j1_161.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j1_162.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j1_163.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_237.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_238.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_239.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_240.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_241.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_242.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_243.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_244.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_245.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_246.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_247.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_248.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_37.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_38.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_39.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_40.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_41.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_42.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_43.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_44.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_45.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_46.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_47.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_48.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_49.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_51.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para j2_52.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_0.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_1.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_10.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_13.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_15.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_18.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_2.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_20.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_21.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_22.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_23.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_24.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_25.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_26.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_36.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_37.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_38.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_39.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_40.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_41.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_42.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_43.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_44.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_55.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_56.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_57.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_58.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_59.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_6.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_60.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_61.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_62.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_63.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_64.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_65.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k1_9.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k2_38.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k2_39.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k2_40.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k2_45.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k2_46.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k2_47.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k2_51.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para k2_53.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# ...
# Aviso: Imagem correspondente para w1_479.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w1_481.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w1_483.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w1_485.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w1_491.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w1_492.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_0.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_100.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_104.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_106.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_109.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_112.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_114.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_12.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_16.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_171.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_175.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_179.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_189.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_19.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_191.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_196.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_199.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_20.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_202.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_205.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_208.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_210.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_212.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_215.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_217.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_22.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_221.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_223.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_227.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_231.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_234.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_240.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_25.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_28.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_31.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_38.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_40.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_43.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_54.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_58.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para w2_63.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para wv_165.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para wv_341.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para wv_356.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para wv_411.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para wv_42.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para wv_456.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para wv_92.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z1_34.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z1_35.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z1_36.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z1_37.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z1_38.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z1_39.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z1_40.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z1_41.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z1_42.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z1_43.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z1_44.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z1_45.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z1_46.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z1_47.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z1_48.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z1_49.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z1_50.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z1_51.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z1_52.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_0.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_1.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_10.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_11.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_12.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_13.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_14.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_15.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_16.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_17.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_18.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_19.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_2.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_20.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_21.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_22.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_23.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_24.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_25.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_26.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_27.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_28.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_29.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_3.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_30.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_31.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_32.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_33.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_34.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_35.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_36.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_37.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_38.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_39.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_4.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_40.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_41.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_5.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_6.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_7.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_8.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z2_9.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_399.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_45.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_46.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_47.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_48.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_49.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_50.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_51.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_52.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_53.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_54.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_55.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_56.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_57.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_58.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_59.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_60.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_61.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_62.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_63.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_64.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_65.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_66.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_67.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_68.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_69.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_70.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_71.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
# Aviso: Imagem correspondente para z3_72.txt não encontrada com extensões ['.jpg', '.png', '.jpeg']. Pulando.
#
# Processamento concluído.
# Total de imagens processadas e salvas no novo dataset: 975
# Total de imagens originais ignoradas (sem objetos de interesse ou erro na imagem): 39

# %% [markdown]
# ## 4. (Opcional) Verificação Visual do Bounding Box
#
# Esta seção permite visualizar os bounding boxes de uma imagem específica **do dataset original** para confirmar se o formato das coordenadas (provavelmente YOLO: `classe_id x_centro_norm y_centro_norm largura_norm altura_norm`) está sendo interpretado corretamente.
#
# **Instruções:**
# 1.  Certifique-se de que a célula de **Configurações** (Célula 4) e a de **Funções Auxiliares** (Célula 6) foram executadas.
# 2.  Altere a variável `IMAGE_TO_INSPECT_BASENAME` na célula de código abaixo para o nome base (sem extensão) de uma imagem que você deseja verificar.
# 3.  Execute a célula.

# %%
# --- Configuração para Inspeção Visual ---
# Mude o nome do arquivo base da imagem que você quer inspecionar (sem .txt ou .jpg)
IMAGE_TO_INSPECT_BASENAME = "a_001" # EXEMPLO, MUDE PARA UM ARQUIVO SEU EXISTENTE

# --- Script de Inspeção ---
def inspect_bounding_boxes(image_basename):
    print(f"\nIniciando inspeção para: {image_basename}")
    
    # Recarregar nomes das classes caso esta célula seja executada independentemente (e as anteriores não)
    class_names_filepath_check = CLASS_NAMES_FILE_ORIGINAL # Usa a variável global
    all_classes_check = load_class_names(class_names_filepath_check)
    if not all_classes_check:
        print("Não foi possível carregar os nomes das classes para inspeção.")
        return

    annotation_filepath_check = os.path.join(ANNOTATION_DIR_ORIGINAL, image_basename + ".txt") # Usa a variável global
    
    # Tenta encontrar a imagem correspondente
    possible_img_extensions_check = [".jpg", ".png", ".jpeg"]
    img_filepath_check = None
    for ext_check in possible_img_extensions_check:
        temp_img_path_check = os.path.join(IMAGE_DIR_ORIGINAL, image_basename + ext_check) # Usa a variável global
        if os.path.exists(temp_img_path_check):
            img_filepath_check = temp_img_path_check
            break
            
    if not os.path.exists(annotation_filepath_check):
        print(f"Arquivo de anotação não encontrado para inspeção: {annotation_filepath_check}")
        return
    if not img_filepath_check:
        print(f"Arquivo de imagem não encontrado para inspeção (base: {image_basename})")
        return

    try:
        img = Image.open(img_filepath_check)
        img_width, img_height = img.size
        
        fig, ax = plt.subplots(1, figsize=(12, 9))
        ax.imshow(img)
        
        with open(annotation_filepath_check, 'r') as f:
            lines = f.readlines()
            if not lines:
                print(f"O arquivo de anotação {annotation_filepath_check} está vazio.")

            for line_idx, line in enumerate(lines):
                parts = line.strip().split()
                if len(parts) == 5:
                    class_id = int(parts[0])
                    x_center_norm = float(parts[1])
                    y_center_norm = float(parts[2])
                    width_norm = float(parts[3])
                    height_norm = float(parts[4])

                    abs_xmin, abs_ymin, abs_xmax, abs_ymax = convert_yolo_to_absolute(
                        x_center_norm, y_center_norm, width_norm, height_norm, img_width, img_height
                    )
                    
                    rect_width = abs_xmax - abs_xmin
                    rect_height = abs_ymax - abs_ymin
                    
                    # Define uma cor para o retângulo e texto
                    # Você pode criar um mapa de cores se quiser cores diferentes por classe
                    box_color = 'red'
                    if class_id < len(all_classes_check) and all_classes_check[class_id] in TARGET_CLASS_NAMES:
                        box_color = 'lime' # Verde para classes de interesse

                    rect = patches.Rectangle((abs_xmin, abs_ymin), rect_width, rect_height, linewidth=2, edgecolor=box_color, facecolor='none')
                    ax.add_patch(rect)
                    
                    class_name_to_display = all_classes_check[class_id] if class_id < len(all_classes_check) else f"ID_{class_id}"
                    
                    plt.text(abs_xmin, abs_ymin - 10, f'{class_name_to_display}', color=box_color, fontsize=10, bbox=dict(facecolor='white', alpha=0.5, pad=0))
                    print(f"  Obj {line_idx+1}: Classe: {class_name_to_display} (ID:{class_id}), YOLO norm: [{x_center_norm:.3f}, {y_center_norm:.3f}, {width_norm:.3f}, {height_norm:.3f}] -> Abs: [{abs_xmin}, {abs_ymin}, {abs_xmax}, {abs_ymax}]")
                else:
                    print(f"  Linha mal formatada ou com número incorreto de partes: {line.strip()}")

        plt.title(f"Inspeção de Bounding Boxes: {image_basename}")
        plt.axis('off') # Desliga os eixos para melhor visualização da imagem
        plt.show()

    except FileNotFoundError:
        print(f"Erro: Imagem ou arquivo de anotação não encontrado para {image_basename}")
    except Exception as e:
        print(f"Ocorreu um erro durante a inspeção de {image_basename}: {e}")

# Executa a inspeção para a imagem configurada
# Certifique-se de que as células de Configuração e Funções Auxiliares foram executadas antes
if IMAGE_TO_INSPECT_BASENAME: # Só executa se um nome de arquivo for fornecido
    inspect_bounding_boxes(IMAGE_TO_INSPECT_BASENAME)
else:
    print("Nenhum nome de arquivo fornecido em IMAGE_TO_INSPECT_BASENAME para inspeção.")
# Out:
# Iniciando inspeção para: a_001
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 90
#      87 # Executa a inspeção para a imagem configurada
#      88 # Certifique-se de que as células de Configuração e Funções Auxiliares foram executadas antes
#      89 if IMAGE_TO_INSPECT_BASENAME: # Só executa se um nome de arquivo for fornecido
# ---> 90     inspect_bounding_boxes(IMAGE_TO_INSPECT_BASENAME)
#      91 else:
#      92     print("Nenhum nome de arquivo fornecido em IMAGE_TO_INSPECT_BASENAME para inspeção.")
#
# Cell In[12], line 11, in inspect_bounding_boxes(image_basename)
#       9 # Recarregar nomes das classes caso esta célula seja executada independentemente (e as anteriores não)
#      10 class_names_filepath_check = os.path.join(AFO_DATASET_ROOT, CLASS_NAMES_FILE)
# ---> 11 all_classes_check = load_class_names(class_names_filepath_check)
#      12 if not all_classes_check:
#      13     print("Não foi possível carregar os nomes das classes para inspeção.")
#
# NameError: name 'load_class_names' is not defined

# %% [markdown]
# ## 5. Próximos Passos
#
# Após executar este notebook:
#
# 1.  **Verifique a Saída:** Navegue até a pasta definida em `OUTPUT_ROOT`. Você deverá encontrar as subpastas `images` e `labels` (ou os nomes que você definiu) contendo apenas as imagens e anotações filtradas.
# 2.  **Use no PyTorch:** Agora você pode usar este dataset limpo para criar sua classe `Dataset` e `DataLoader` no PyTorch, conforme discutido anteriormente. As anotações estarão no formato YOLO (`classe_id x_centro y_centro largura altura` - todos normalizados), que é comum e pode ser facilmente lido e convertido para o formato que seu modelo PyTorch espera (geralmente tensores de bounding boxes `[xmin, ymin, xmax, ymax]` e labels).
# 3.  **Iteração:** Se necessário, ajuste as `TARGET_CLASS_NAMES` ou outras configurações e re-execute o notebook.
